# %%
import pandas as pd

# %%
pd.read_table('./shortbred/example_quantify2/markers.tab')
# Out:
#                                          Family  \
# 0                                     NP_214776
# 1                                     NP_214776
# 2                                     NP_214776
# 3                                     NP_214776
# 4                                     NP_214776
# 5                                     NP_214776
# 6                                     NP_214776
# 7                                     NP_753952
# 8                                        P13246
# 9                                        P13246
# 10                                       P13246
# 11                                       P13246
# 12                                       P13246
# 13                                       P13246
# 14                                       P13246
# 15                                       P13246
# 16                                       P23181
# 17                                       P23181
# ...
